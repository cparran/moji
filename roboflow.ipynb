# %%
#

# %%
! pip install inference
# Out:
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached wheel-0.42.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached setuptools-69.1.1-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached pydantic-2.6.3-py3-none-any.whl.metadata (84 kB)
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached cryptography-42.0.5-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
# ...
#   Using cached tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# ...

# %%
# import the inference-sdk
from inference_sdk import InferenceHTTPClient

# initialize the client
CLIENT = InferenceHTTPClient(
    api_url="http://detect.roboflow.com",
    api_key="JVuvSUZ2T8BQEtoGVvtv"
)

# infer on a local image
result = CLIENT.infer("/home/carol/code/cparran/MOJI/data/_05.jpg", model_id="manga-text-detection/2")

# %%
# Imprimimos las predicciones
result
# Out:
# {'time': 0.26694242500002474,
#  'image': {'width': 782, 'height': 1079},
#  'predictions': [{'x': 388.8193359375,
#    'y': 294.51220703125,
#    'width': 136.982421875,
#    'height': 268.6962890625,
#    'confidence': 0.9767366647720337,
#    'class': 'text_bubble',
#    'class_id': 0,
#    'detection_id': '24c1ec3c-e6dc-408a-b238-2cc61086c31b'},
#   {'x': 437.2900390625,
#    'y': 859.30126953125,
#    'width': 113.80078125,
#    'height': 268.6962890625,
#    'confidence': 0.9732743501663208,
#    'class': 'text_bubble',
#    'class_id': 0,
#    'detection_id': 'f012336a-fcc4-4663-8e0c-7fc0272a54ae'},
#   {'x': 656.98876953125,
#    'y': 784.48779296875,
#    'width': 66.3837890625,
#    'height': 116.9619140625,
#    'confidence': 0.9716801643371582,
#    'class': 'text_bubble',
#    'class_id': 0,
#    'detection_id': 'bfe05135-95f3-4c32-8885-b6087521509b'},
#   {'x': 277.65283203125,
#    'y': 619.05517578125,
#    'width': 93.7802734375,
#    'height': 144.3583984375,
# ...

# %% [markdown]
# # Otro modo de conectarse a la API

# %%
! pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 166.4 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 431.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 535.0 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 173.4 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="JVuvSUZ2T8BQEtoGVvtv")
project = rf.workspace().project("manga-text-detection")
model = project.version(2).model

# infer on a local image
print(model.predict("/home/carol/code/cparran/MOJI/data/_05.jpg", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("/home/carol/code/cparran/MOJI/data/_05.jpg", confidence=40, overlap=30).save("prediction.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %% [markdown]
# # Visualización

# %%
from inference import get_model
import supervision as sv
import cv2

#Load model
model = get_model(model_id="manga-text-detection/2")

#Load image with cv2
image = cv2.imread("/home/carol/code/cparran/MOJI/data/_05.jpg")

#Run inference
results = model.infer(image)

#Load results into Supervision Detection API
detections = sv.Detections.from_inference(
    results[0].dict(by_alias=True, exclude_none=True)
)

#Create Supervision annotators
bounding_box_annotator = sv.BoundingBoxAnnotator()
label_annotator = sv.LabelAnnotator()

#Extract labels array from inference results
labels = [p.class_name for p in results[0].predictions]



#Apply results to image using Supervision annotators
annotated_image = bounding_box_annotator.annotate(scene=image, detections=detections)
annotated_image = label_annotator.annotate(
    scene=annotated_image, detections=detections, labels=labels
)

#Write annotated image to file or display image
cv2.imwrite("_05.jpg", annotated_image)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
# True

# %%
# Visualizamos la imagen segmentada

sv.plot_image(annotated_image)
